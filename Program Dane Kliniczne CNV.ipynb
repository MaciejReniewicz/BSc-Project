# %%
import pandas as pd
import numpy as np

# %%
df =  pd.read_csv("set.CNV_SNP.clinical.all.csv",sep = ';',decimal=',')
df = df.rename(columns = {'Unnamed: 0':'PatientID'})
#vital status, patologic stage, gender, radiotion teraphy, histological type, race
df = df[['PatientID','vitalstatus','pathologicstage','gender','radiationtherapy','histologicaltype','race']]

# %%
df
# Out:
#         PatientID  vitalstatus pathologicstage  gender radiationtherapy  \
# 0    TCGA-05-4245            0      stage iiia    male               no
# 1    TCGA-05-4382            0        stage ib    male              yes
# 2    TCGA-05-4384            0      stage iiia    male              yes
# 3    TCGA-05-4396            1      stage iiib    male              NaN
# 4    TCGA-05-4402            1        stage iv  female               no
# 5    TCGA-05-4405            0        stage ib  female               no
# 6    TCGA-05-4410            0        stage ib    male              NaN
# 7    TCGA-05-4418            1      stage iiia    male              NaN
# 8    TCGA-05-4427            0       stage iib  female               no
# 9    TCGA-05-4434            1        stage iv  female              NaN
# 10   TCGA-05-5420            0      stage iiia    male              NaN
# 11   TCGA-38-4629            1       stage iib    male               no
# 12   TCGA-38-4630            1        stage ib  female               no
# 13   TCGA-38-4631            1        stage ib  female               no
# 14   TCGA-38-6178            0      stage iiia  female               no
# 15   TCGA-38-7271            1        stage ia  female               no
# 16   TCGA-44-2655            0        stage ia  female               no
# 17   TCGA-44-2661            0        stage ia  female               no
# 18   TCGA-44-2662            0        stage ib    male               no
# 19   TCGA-44-6146            0       stage iib    male               no
# 20   TCGA-44-6147            0        stage ia  female               no
# 21   TCGA-44-6776            0        stage ia  female               no
# 22   TCGA-44-7661            1        stage ib  female               no
# 23   TCGA-44-7670            0       stage iia  female               no
# 24   TCGA-44-7671            0        stage ib    male               no
# 25   TCGA-44-8119            0       stage iib    male               no
# 26   TCGA-44-A47F            0       stage iib    male               no
# 27   TCGA-49-4501            1        stage ib  female               no
# 28   TCGA-49-6742            1       stage iia    male               no
# 29   TCGA-49-6745            0      stage iiia    male               no
# ..            ...          ...             ...     ...              ...
# 492  TCGA-L9-A7SV            0       stage iia    male               no
# 493  TCGA-L9-A8F4            0        stage ib  female              yes
# 494  TCGA-MN-A4N4            0        stage ia    male               no
# 495  TCGA-MN-A4N5            0        stage ia    male               no
# 496  TCGA-MP-A4SV            1        stage ib    male               no
# 497  TCGA-MP-A4SW            1       stage iib    male               no
# 498  TCGA-MP-A4SY            1       stage iib    male               no
# 499  TCGA-MP-A4T2            1        stage ia    male               no
# 500  TCGA-MP-A4T4            1       stage iib  female               no
# 501  TCGA-MP-A4T6            1      stage iiia  female               no
# 502  TCGA-MP-A4T7            1        stage iv  female               no
# 503  TCGA-MP-A4T9            1      stage iiia  female              yes
# 504  TCGA-MP-A4TE            1       stage iia    male               no
# 505  TCGA-MP-A4TF            1       stage iia  female               no
# 506  TCGA-MP-A4TH            0        stage ia  female               no
# 507  TCGA-MP-A4TI            1       stage iia    male              NaN
# 508  TCGA-MP-A4TJ            1        stage ia  female               no
# 509  TCGA-MP-A4TK            1       stage iib  female               no
# 510  TCGA-MP-A5C7            0        stage ib  female               no
# 511  TCGA-NJ-A4YF            0        stage ia  female               no
# 512  TCGA-NJ-A4YG            0        stage ib    male               no
# 513  TCGA-NJ-A4YI            1      stage iiia  female               no
# 514  TCGA-NJ-A4YP            0        stage ib    male               no
# 515  TCGA-NJ-A4YQ            0        stage ia  female               no
# 516  TCGA-NJ-A55A            0        stage ib  female               no
# 517  TCGA-NJ-A55O            0       stage iia  female               no
# 518  TCGA-NJ-A55R            0        stage ia    male               no
# 519  TCGA-NJ-A7XG            0      stage iiia    male               no
# 520  TCGA-O1-A52J            1        stage ia  female               no
# 521  TCGA-S2-AA1A            0        stage ia  female               no
#
#                                       histologicaltype  \
# 0    lung adenocarcinoma- not otherwise specified (...
# 1                    lung adenocarcinoma mixed subtype
# 2                    lung adenocarcinoma mixed subtype
# 3                    lung adenocarcinoma mixed subtype
# 4                    lung adenocarcinoma mixed subtype
# 5                    lung adenocarcinoma mixed subtype
# 6                    lung adenocarcinoma mixed subtype
# 7                    lung adenocarcinoma mixed subtype
# 8                    lung adenocarcinoma mixed subtype
# 9                    lung adenocarcinoma mixed subtype
# 10   lung adenocarcinoma- not otherwise specified (...
# 11   lung adenocarcinoma- not otherwise specified (...
# 12                       lung papillary adenocarcinoma
# 13   lung adenocarcinoma- not otherwise specified (...
# 14   lung adenocarcinoma- not otherwise specified (...
# 15   lung adenocarcinoma- not otherwise specified (...
# 16   lung adenocarcinoma- not otherwise specified (...
# 17   lung adenocarcinoma- not otherwise specified (...
# 18   lung adenocarcinoma- not otherwise specified (...
# 19                        lung mucinous adenocarcinoma
# 20   lung adenocarcinoma- not otherwise specified (...
# 21   lung adenocarcinoma- not otherwise specified (...
# 22   lung adenocarcinoma- not otherwise specified (...
# 23   lung adenocarcinoma- not otherwise specified (...
# 24                   lung adenocarcinoma mixed subtype
# 25   lung adenocarcinoma- not otherwise specified (...
# 26   lung adenocarcinoma- not otherwise specified (...
# 27   lung adenocarcinoma- not otherwise specified (...
# 28                        mucinous (colloid) carcinoma
# 29   lung adenocarcinoma- not otherwise specified (...
# ..                                                 ...
# 492  lung adenocarcinoma- not otherwise specified (...
# 493  lung adenocarcinoma- not otherwise specified (...
# 494  lung adenocarcinoma- not otherwise specified (...
# 495  lung adenocarcinoma- not otherwise specified (...
# 496  lung adenocarcinoma- not otherwise specified (...
# 497  lung adenocarcinoma- not otherwise specified (...
# 498  lung adenocarcinoma- not otherwise specified (...
# 499  lung adenocarcinoma- not otherwise specified (...
# 500  lung adenocarcinoma- not otherwise specified (...
# 501  lung adenocarcinoma- not otherwise specified (...
# 502  lung adenocarcinoma- not otherwise specified (...
# 503  lung adenocarcinoma- not otherwise specified (...
# 504  lung adenocarcinoma- not otherwise specified (...
# 505  lung adenocarcinoma- not otherwise specified (...
# 506  lung adenocarcinoma- not otherwise specified (...
# 507  lung adenocarcinoma- not otherwise specified (...
# 508                    lung signet ring adenocarcinoma
# 509  lung adenocarcinoma- not otherwise specified (...
# 510  lung adenocarcinoma- not otherwise specified (...
# 511                  lung adenocarcinoma mixed subtype
# 512  lung adenocarcinoma- not otherwise specified (...
# 513                      lung papillary adenocarcinoma
# 514                      lung papillary adenocarcinoma
# 515  lung adenocarcinoma- not otherwise specified (...
# 516  lung adenocarcinoma- not otherwise specified (...
# 517                       mucinous (colloid) carcinoma
# 518  lung adenocarcinoma- not otherwise specified (...
# 519  lung adenocarcinoma- not otherwise specified (...
# 520  lung adenocarcinoma- not otherwise specified (...
# 521         lung bronchioloalveolar carcinoma mucinous
#
#                           race
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                       white
# 12                       white
# 13                       white
# 14                       white
# 15                       white
# 16                       white
# 17                       white
# 18                       white
# 19                       white
# 20                       white
# 21                       white
# 22                       white
# 23                       white
# 24   black or african american
# 25                       white
# 26                       white
# 27                       white
# 28                       white
# 29                       white
# ..                         ...
# 492  black or african american
# 493  black or african american
# 494                      white
# 495                      white
# 496                        NaN
# 497                      white
# 498                      white
# 499                      white
# 500                      white
# 501                      white
# 502                        NaN
# 503                      white
# 504                      white
# 505                      white
# 506                      white
# 507                      white
# 508                        NaN
# 509                        NaN
# 510                      white
# 511  black or african american
# 512                      white
# 513                      white
# 514                      white
# 515                      white
# 516                      white
# 517                      white
# 518                      white
# 519  black or african american
# 520                      white
# 521  black or african american
#
# [522 rows x 7 columns]

# %%
df['vitalstatus'].value_counts()
# Out:
# 0    334
# 1    188
# Name: vitalstatus, dtype: int64

# %%
df.groupby('vitalstatus')['pathologicstage'].value_counts()
# Out:
# vitalstatus  pathologicstage
# 0            stage ia           105
#              stage ib           101
#              stage iib           41
#              stage iiia          34
#              stage iia           29
#              stage iv            10
#              stage i              4
#              stage iiib           4
# 1            stage iiia          40
#              stage ib            39
#              stage iib           32
#              stage ia            29
#              stage iia           21
#              stage iv            16
#              stage iiib           7
#              stage i              1
#              stage ii             1
# Name: pathologicstage, dtype: int64

# %%
df.groupby('vitalstatus')['gender'].value_counts()
# Out:
# vitalstatus  gender
# 0            female    182
#              male      152
# 1            female     98
#              male       90
# Name: gender, dtype: int64

# %%
df.groupby('vitalstatus')['radiationtherapy'].value_counts()
# Out:
# vitalstatus  radiationtherapy
# 0            no                  275
#              yes                  26
# 1            no                  139
#              yes                  35
# Name: radiationtherapy, dtype: int64

# %%
df.groupby('vitalstatus')['histologicaltype'].value_counts()
# Out:
# vitalstatus  histologicaltype
# 0            lung adenocarcinoma- not otherwise specified (nos)    194
#              lung adenocarcinoma mixed subtype                      71
#              lung acinar adenocarcinoma                             16
#              lung papillary adenocarcinoma                          16
#              lung bronchioloalveolar carcinoma nonmucinous          14
#              mucinous (colloid) carcinoma                            8
#              lung solid pattern predominant adenocarcinoma           5
#              lung bronchioloalveolar carcinoma mucinous              4
#              lung clear cell adenocarcinoma                          2
#              lung micropapillary adenocarcinoma                      2
#              lung mucinous adenocarcinoma                            2
# 1            lung adenocarcinoma- not otherwise specified (nos)    133
#              lung adenocarcinoma mixed subtype                      36
#              lung papillary adenocarcinoma                           7
#              lung bronchioloalveolar carcinoma nonmucinous           5
#              lung acinar adenocarcinoma                              2
#              mucinous (colloid) carcinoma                            2
#              lung bronchioloalveolar carcinoma mucinous              1
#              lung micropapillary adenocarcinoma                      1
#              lung signet ring adenocarcinoma                         1
# Name: histologicaltype, dtype: int64

# %%
df.groupby('vitalstatus')['race'].value_counts()
# Out:
# vitalstatus  race
# 0            white                               248
#              black or african american            36
#              asian                                 7
#              american indian or alaska native      1
# 1            white                               145
#              black or african american            17
#              asian                                 1
# Name: race, dtype: int64
